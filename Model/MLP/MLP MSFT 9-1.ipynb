# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
# Đọc dữ liệu từ file CSV
df = pd.read_csv('D:/IS403_O21_HTCL_15/Dataset/MSFT.csv')

# Chọn cột 'Close' và cột 'Date'
df = df[['Date', 'Close']]

# Chuyển đổi cột 'Date' thành định dạng datetime
df['Date'] = pd.to_datetime(df['Date'])

# Thiết lập cột 'Date' làm chỉ mục
df.set_index('Date', inplace=True)

# Vẽ biểu đồ dữ liệu
plt.figure(figsize=(20, 12))
plt.plot(df.index, df, label='Data AAPL', color='blue')
plt.show()

# Kiểm tra dữ liệu
print(df.head())
print(df.describe())

# Chuẩn hóa dữ liệu
scaler = MinMaxScaler()
df['Close'] = scaler.fit_transform(df[['Close']])
# Out:
#                 Close
# Date
# 2018-03-01  92.849998
# 2018-03-02  93.050003
# 2018-03-05  93.639999
# 2018-03-06  93.320000
# 2018-03-07  93.860001
#              Close
# count  1574.000000
# mean    229.935578
# std      92.452863
# min      87.180000
# 25%     138.540005
# 50%     236.709999
# 75%     298.262490
# max     430.519989

# %%
# Định nghĩa bước thời gian
time_window = 40

#Chia pha train - test
train_size = int(len(df) * 0.9)
train_data = df[0:train_size]
test_data = df[train_size:len(df)]

print(train_data.tail())
print(test_data.head())
print(len(test_data))
#Lấy thêm time_window ngày từ tập train vào tập test để dự đoán ngày đầu tiên của tập test
test_data = pd.concat([train_data[-time_window:], test_data])

print(test_data.head(10))
print(len(test_data))
# Out:
#                Close
# Date
# 2023-10-09  0.706705
# 2023-10-10  0.702540
# 2023-10-11  0.714277
# 2023-10-12  0.710608
# 2023-10-13  0.700618
#                Close
# Date
# 2023-10-16  0.714918
# 2023-10-17  0.713229
# 2023-10-18  0.707549
# 2023-10-19  0.711074
# 2023-10-20  0.697530
# 158
#                Close
# Date
# 2023-08-18  0.667851
# 2023-08-21  0.683579
# 2023-08-22  0.685268
# 2023-08-23  0.698491
# 2023-08-24  0.678016
# 2023-08-25  0.686783
# 2023-08-28  0.688880
# 2023-08-29  0.702598
# 2023-08-30  0.703705
# 2023-08-31  0.700705
# 198

# %%
# Tạo hàm để tạo tập dữ liệu huấn luyện
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)


# Tạo dữ liệu cho mô hình
X_train, y_train = create_dataset(train_data.values, time_window)
X_test, y_test = create_dataset(test_data.values, time_window)

# %%
# Xây dựng và huấn luyện mô hình MLP
# Build the model
model = Sequential()
model.add(Dense(100, input_dim=X_train.shape[1], activation='relu'))  # Input layer
model.add(Dense(50, activation='relu'))  # Hidden layer
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# model.fit(X_train, y_train)
# Out:
# c:\Users\GIAHUY\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0093 - val_loss: 0.0021
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4842e-04 - val_loss: 0.0012
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6405e-04 - val_loss: 0.0023
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0823e-04 - val_loss: 7.0556e-04
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4115e-04 - val_loss: 5.9990e-04
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0325e-04 - val_loss: 6.1348e-04
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0133e-04 - val_loss: 6.3946e-04
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1772e-04 - val_loss: 5.5533e-04
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6779e-04 - val_loss: 0.0013
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.8426e-04 - val_loss: 5.8309e-04
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7341e-04 - val_loss: 6.7192e-04
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2910e-04 - val_loss: 6.0795e-04
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1033e-04 - val_loss: 5.0018e-04
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5379e-04 - val_loss: 5.7572e-04
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5468e-04 - val_loss: 0.0015
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0666e-04 - val_loss: 5.6936e-04
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4226e-04 - val_loss: 4.9702e-04
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8185e-04 - val_loss: 5.1848e-04
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0297e-04 - val_loss: 7.6170e-04
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0165e-04 - val_loss: 5.8460e-04
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3662e-04 - val_loss: 4.9508e-04
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3887e-04 - val_loss: 4.4399e-04
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2839e-04 - val_loss: 4.9664e-04
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4291e-04 - val_loss: 4.5653e-04
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1883e-04 - val_loss: 4.4937e-04
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0441e-04 - val_loss: 4.7137e-04
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2512e-04 - val_loss: 7.5078e-04
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0397e-04 - val_loss: 4.1433e-04
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0569e-04 - val_loss: 3.9902e-04
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0622e-04 - val_loss: 7.6941e-04
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0151e-04 - val_loss: 3.9598e-04
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9326e-04 - val_loss: 4.7170e-04
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2935e-04 - val_loss: 3.9769e-04
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0592e-04 - val_loss: 4.8510e-04
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0745e-04 - val_loss: 4.2011e-04
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9540e-04 - val_loss: 3.7455e-04
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8298e-04 - val_loss: 6.9807e-04
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0758e-04 - val_loss: 6.9495e-04
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2914e-04 - val_loss: 4.5616e-04
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3558e-04 - val_loss: 3.9759e-04
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5593e-04 - val_loss: 4.0634e-04
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1198e-04 - val_loss: 4.4564e-04
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1274e-04 - val_loss: 4.2090e-04
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0487e-04 - val_loss: 3.5495e-04
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6951e-04 - val_loss: 7.2751e-04
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5189e-04 - val_loss: 4.9986e-04
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3419e-04 - val_loss: 5.0656e-04
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8368e-04 - val_loss: 3.4955e-04
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8043e-04 - val_loss: 3.5880e-04
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6514e-04 - val_loss: 3.6010e-04
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8688e-04 - val_loss: 7.1422e-04
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7546e-04 - val_loss: 7.1242e-04
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9230e-04 - val_loss: 4.5727e-04
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8158e-04 - val_loss: 7.6906e-04
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6684e-04 - val_loss: 3.5976e-04
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0035e-04 - val_loss: 6.9986e-04
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9592e-04 - val_loss: 6.5741e-04
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4319e-04 - val_loss: 4.2645e-04
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7661e-04 - val_loss: 3.3995e-04
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7946e-04 - val_loss: 3.8085e-04
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7686e-04 - val_loss: 5.5532e-04
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8870e-04 - val_loss: 4.1167e-04
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9499e-04 - val_loss: 0.0012
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9080e-04 - val_loss: 3.3372e-04
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9174e-04 - val_loss: 3.6970e-04
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2226e-04 - val_loss: 4.6952e-04
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4318e-04 - val_loss: 3.3541e-04
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5976e-04 - val_loss: 3.5686e-04
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6644e-04 - val_loss: 3.7346e-04
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0314e-04 - val_loss: 3.6851e-04
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0995e-04 - val_loss: 3.1523e-04
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7371e-04 - val_loss: 3.2019e-04
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6075e-04 - val_loss: 5.9025e-04
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0198e-04 - val_loss: 0.0017
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9180e-04 - val_loss: 3.1690e-04
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6022e-04 - val_loss: 3.8512e-04
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9685e-04 - val_loss: 6.6131e-04
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3059e-04 - val_loss: 3.6068e-04
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6321e-04 - val_loss: 4.0212e-04
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7993e-04 - val_loss: 8.0568e-04
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2835e-04 - val_loss: 4.7157e-04
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9098e-04 - val_loss: 6.3491e-04
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7768e-04 - val_loss: 5.6434e-04
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8927e-04 - val_loss: 4.7482e-04
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0029e-04 - val_loss: 3.2081e-04
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6380e-04 - val_loss: 3.1179e-04
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6469e-04 - val_loss: 8.4545e-04
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0641e-04 - val_loss: 0.0011
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7054e-04 - val_loss: 3.2386e-04
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7069e-04 - val_loss: 4.7564e-04
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7388e-04 - val_loss: 4.7646e-04
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9369e-04 - val_loss: 3.3860e-04
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5989e-04 - val_loss: 3.0912e-04
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7661e-04 - val_loss: 3.7805e-04
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7570e-04 - val_loss: 3.6941e-04
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7358e-04 - val_loss: 7.1014e-04
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7459e-04 - val_loss: 3.3076e-04
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6278e-04 - val_loss: 3.7770e-04
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6980e-04 - val_loss: 3.0381e-04
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5296e-04 - val_loss: 3.5762e-04

# %%
# Dự đoán
# train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

test_data = test_data[time_window:]

print(len(X_test))
print(len(y_test))
print(len(test_data))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 158
# 158
# 158

# %%
# Đánh giá mô hình
# train_predict = scaler.inverse_transform(train_predict.reshape(-1, 1))
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
# Reshape test_predict for compatibility with DataFrame creation
test_predict_reshaped = test_predict.reshape(-1, 1)

# Create a DataFrame with test_data index and test_predict values
predicted_test = pd.DataFrame(test_predict_reshaped, index=test_data.index, columns=["predicted_value"])

# %%
# Hàm dự đoán ngày tiếp theo
def predict_future(data, model, window_size, days):
    future_preds = []
    last_window = list(data[-window_size:])
    for _ in range(days):
        next_pred = model.predict(np.array(last_window).reshape(1, window_size))
        future_preds.append(next_pred[0, 0])  # Accessing the first element directly
        last_window.append(next_pred[0, 0])
        last_window.pop(0)
    return future_preds

# Dự đoán 90 ngày tiếp theo
days_to_predict = 90
future_predictions = predict_future(test_data['Close'].values, model, time_window, days_to_predict)

# Tạo các ngày tiếp theo
next_days_index = pd.date_range(start=test_data.index[-1] + pd.Timedelta(days=1), periods=days_to_predict)

# Tạo DataFrame cho các dự đoán tiếp theo
future_df = pd.DataFrame(future_predictions, index=next_days_index, columns=['Close Predict'])

train_data['Close'] = scaler.inverse_transform(train_data[['Close']])
test_data['Close'] = scaler.inverse_transform(test_data[['Close']])
future_df['Close Predict'] = scaler.inverse_transform(future_df[['Close Predict']])

print(future_df.head())
print(next_days_index)

# print(train_data.tail())
print(test_data.tail())
# print(predicted_test.head())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#             Close Predict
# 2024-06-01     420.051514
# 2024-06-02     420.490326
# 2024-06-03     423.621277
# 2024-06-04     423.046387
# 2024-06-05     424.661224
# DatetimeIndex(['2024-06-01', '2024-06-02', '2024-06-03', '2024-06-04',
#                '2024-06-05', '2024-06-06', '2024-06-07', '2024-06-08',
#                '2024-06-09', '2024-06-10', '2024-06-11', '2024-06-12',
#                '2024-06-13', '2024-06-14', '2024-06-15', '2024-06-16',
#                '2024-06-17', '2024-06-18', '2024-06-19', '2024-06-20',
#                '2024-06-21', '2024-06-22', '2024-06-23', '2024-06-24',
#                '2024-06-25', '2024-06-26', '2024-06-27', '2024-06-28',
#                '2024-06-29', '2024-06-30', '2024-07-01', '2024-07-02',
#                '2024-07-03', '2024-07-04', '2024-07-05', '2024-07-06',
#                '2024-07-07', '2024-07-08', '2024-07-09', '2024-07-10',
#                '2024-07-11', '2024-07-12', '2024-07-13', '2024-07-14',
#                '2024-07-15', '2024-07-16', '2024-07-17', '2024-07-18',
#                '2024-07-19', '2024-07-20', '2024-07-21', '2024-07-22',
#                '2024-07-23', '2024-07-24', '2024-07-25', '2024-07-26',
#                '2024-07-27', '2024-07-28', '2024-07-29', '2024-07-30',
#                '2024-07-31', '2024-08-01', '2024-08-02', '2024-08-03',
#                '2024-08-04', '2024-08-05', '2024-08-06', '2024-08-07',
#                '2024-08-08', '2024-08-09', '2024-08-10', '2024-08-11',
#                '2024-08-12', '2024-08-13', '2024-08-14', '2024-08-15',
#                '2024-08-16', '2024-08-17', '2024-08-18', '2024-08-19',
#                '2024-08-20', '2024-08-21', '2024-08-22', '2024-08-23',
#                '2024-08-24', '2024-08-25', '2024-08-26', '2024-08-27',
#                '2024-08-28', '2024-08-29'],
#               dtype='datetime64[ns]', freq='D')
#                  Close
# Date
# 2024-05-24  430.160004
# 2024-05-28  430.320007
# 2024-05-29  429.170013
# 2024-05-30  414.670013
# 2024-05-31  415.130005
# C:\Users\GIAHUY\AppData\Local\Temp\ipykernel_11628\2781551278.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Close'] = scaler.inverse_transform(train_data[['Close']])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Đánh giá MAE
mae = mean_absolute_error(test_data['Close'], predicted_test['predicted_value'])
print("Mean Absolute Error (MAE):", mae)

# Đánh giá MSE
mse = mean_squared_error(test_data['Close'], predicted_test['predicted_value'])
print("Mean Squared Error (MSE):", mse)

# Đánh giá RMSE
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Đánh giá MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(test_data['Close'], predicted_test['predicted_value'])
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Error (MAE): 4.408030443693132
# Mean Squared Error (MSE): 32.80713449103973
# Root Mean Squared Error (RMSE): 5.727751259529322
# Mean Absolute Percentage Error (MAPE): 1.1199196771243638

# %%
# Thêm phần tử cuối của train_data vào đầu của test_data và df_predicted
last_train_data = train_data.iloc[-1]
test_data = pd.concat([pd.DataFrame(last_train_data).T, test_data])
predicted_test = pd.concat([pd.DataFrame(last_train_data['Close'], index=[test_data.index[0] - pd.Timedelta(days=1)], columns=["predicted_value"]), predicted_test])

# Tạo 3 phần dữ liệu cho 90 ngày tiếp theo
future_df_1 = future_df[:30]
future_df_2 = future_df[30:60]
future_df_3 = future_df[60:]

# Vẽ biểu đồ dự đoán và thực tế
plt.figure(figsize=(20, 12))
plt.plot(train_data.index, train_data, label='Actual Train', color='blue')
plt.plot(test_data.index, test_data, label='Actual Test', color='red')
plt.plot(predicted_test.index, predicted_test, label='Predicted Test', color='orange')
plt.plot(future_df_1.index, future_df_1, label='Predicted Day 1-30', color='green')
plt.plot(future_df_2.index, future_df_2, label='Predicted Day 31-60', color='purple')
plt.plot(future_df_3.index, future_df_3, label='Predicted Day 61-90', color='yellow')
plt.legend()
plt.show()
