# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
# Đọc dữ liệu từ file CSV
df = pd.read_csv('D:/IS403_O21_HTCL_15/Dataset/GOOG.csv')

# Chọn cột 'Close' và cột 'Date'
df = df[['Date', 'Close']]

# Chuyển đổi cột 'Date' thành định dạng datetime
df['Date'] = pd.to_datetime(df['Date'])

# Thiết lập cột 'Date' làm chỉ mục
df.set_index('Date', inplace=True)

# Vẽ biểu đồ dữ liệu
plt.figure(figsize=(20, 12))
plt.plot(df.index, df, label='Data AAPL', color='blue')
plt.show()

# Kiểm tra dữ liệu
print(df.head())
print(df.describe())

# Chuẩn hóa dữ liệu
scaler = MinMaxScaler()
df['Close'] = scaler.fit_transform(df[['Close']])
# Out:
#                 Close
# Date
# 2018-03-01  53.476002
# 2018-03-02  53.945999
# 2018-03-05  54.546501
# 2018-03-06  54.752998
# 2018-03-07  55.481998
#              Close
# count  1574.000000
# mean     96.587886
# std      34.376003
# min      48.811001
# 25%      61.208501
# 50%      94.959999
# 75%     129.118252
# max     179.539993

# %%
# Định nghĩa bước thời gian
time_window = 40

#Chia pha train - test
train_size = int(len(df) * 0.8)
train_data = df[0:train_size]
test_data = df[train_size:len(df)]

print(train_data.tail())
print(test_data.head())
print(len(test_data))
#Lấy thêm time_window ngày từ tập train vào tập test để dự đoán ngày đầu tiên của tập test
test_data = pd.concat([train_data[-time_window:], test_data])

print(test_data.head(10))
print(len(test_data))
# Out:
#                Close
# Date
# 2023-02-23  0.323257
# 2023-02-24  0.310100
# 2023-02-27  0.315837
# 2023-02-28  0.317366
# 2023-03-01  0.318973
#                Close
# Date
# 2023-03-02  0.332742
# 2023-03-03  0.345822
# 2023-03-06  0.357755
# 2023-03-07  0.346970
# 2023-03-08  0.350641
# 315
#                Close
# Date
# 2023-01-03  0.312777
# 2023-01-04  0.305204
# 2023-01-05  0.290364
# 2023-01-06  0.300997
# 2023-01-09  0.305892
# 2023-01-10  0.309258
# 2023-01-11  0.332359
# 2023-01-12  0.329682
# 2023-01-13  0.336490
# 2023-01-17  0.331594
# 355

# %%
# Tạo hàm để tạo tập dữ liệu huấn luyện
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)


# Tạo dữ liệu cho mô hình
X_train, y_train = create_dataset(train_data.values, time_window)
X_test, y_test = create_dataset(test_data.values, time_window)

# %%
# Xây dựng và huấn luyện mô hình MLP
# Build the model
model = Sequential()
model.add(Dense(100, input_dim=X_train.shape[1], activation='relu'))  # Input layer
model.add(Dense(50, activation='relu'))  # Hidden layer
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# model.fit(X_train, y_train)
# Out:
# c:\Users\GIAHUY\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0060 - val_loss: 0.0032
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3422e-04 - val_loss: 0.0012
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8935e-04 - val_loss: 0.0011
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5563e-04 - val_loss: 0.0012
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3075e-04 - val_loss: 0.0014
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6914e-04 - val_loss: 9.9316e-04
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4586e-04 - val_loss: 9.9481e-04
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2178e-04 - val_loss: 9.2936e-04
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7739e-04 - val_loss: 0.0011
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4454e-04 - val_loss: 8.8052e-04
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7952e-04 - val_loss: 0.0014
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2831e-04 - val_loss: 8.3456e-04
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0536e-04 - val_loss: 8.6031e-04
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0249e-04 - val_loss: 7.7694e-04
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4196e-04 - val_loss: 8.1712e-04
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1043e-04 - val_loss: 8.0654e-04
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9779e-04 - val_loss: 9.0454e-04
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3045e-04 - val_loss: 7.4008e-04
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3778e-04 - val_loss: 6.9765e-04
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7400e-04 - val_loss: 0.0014
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3429e-04 - val_loss: 6.9555e-04
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5083e-04 - val_loss: 0.0011
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6371e-04 - val_loss: 7.2462e-04
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4441e-04 - val_loss: 8.5424e-04
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7623e-04 - val_loss: 0.0017
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0724e-04 - val_loss: 6.9120e-04
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9078e-04 - val_loss: 6.7076e-04
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0177e-04 - val_loss: 6.6113e-04
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2297e-04 - val_loss: 6.5995e-04
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0428e-04 - val_loss: 6.6362e-04
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8620e-04 - val_loss: 0.0017
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1261e-04 - val_loss: 6.3621e-04
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7499e-04 - val_loss: 6.6076e-04
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7709e-04 - val_loss: 6.1516e-04
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8285e-04 - val_loss: 6.4103e-04
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9136e-04 - val_loss: 0.0017
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9055e-04 - val_loss: 7.8385e-04
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9084e-04 - val_loss: 6.3944e-04
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7058e-04 - val_loss: 6.8952e-04
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3943e-04 - val_loss: 9.0464e-04
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5577e-04 - val_loss: 8.3887e-04
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9929e-04 - val_loss: 8.5444e-04
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8746e-04 - val_loss: 8.1390e-04
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3282e-04 - val_loss: 0.0012
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8637e-04 - val_loss: 7.4174e-04
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3460e-04 - val_loss: 6.1756e-04
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3972e-04 - val_loss: 6.7110e-04
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1241e-04 - val_loss: 6.0629e-04
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0408e-04 - val_loss: 8.5096e-04
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3003e-04 - val_loss: 9.1603e-04
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3476e-04 - val_loss: 5.9444e-04
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7919e-04 - val_loss: 6.5464e-04
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5830e-04 - val_loss: 5.8900e-04
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1669e-04 - val_loss: 6.9799e-04
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9750e-04 - val_loss: 0.0015
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0917e-04 - val_loss: 5.8066e-04
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0812e-04 - val_loss: 6.5133e-04
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7765e-04 - val_loss: 6.2059e-04
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1013e-04 - val_loss: 5.6427e-04
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7378e-04 - val_loss: 5.6926e-04
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6780e-04 - val_loss: 9.6507e-04
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0212e-04 - val_loss: 9.4076e-04
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7572e-04 - val_loss: 7.1852e-04
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6167e-04 - val_loss: 6.2841e-04
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5995e-04 - val_loss: 5.7412e-04
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1355e-04 - val_loss: 5.5815e-04
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2007e-04 - val_loss: 6.9585e-04
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8403e-04 - val_loss: 5.5912e-04
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0700e-04 - val_loss: 7.5399e-04
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6866e-04 - val_loss: 5.5219e-04
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1662e-04 - val_loss: 7.4835e-04
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8356e-04 - val_loss: 5.8557e-04
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2118e-04 - val_loss: 8.2455e-04
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1671e-04 - val_loss: 5.4373e-04
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5512e-04 - val_loss: 6.2392e-04
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5755e-04 - val_loss: 5.4567e-04
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1948e-04 - val_loss: 0.0014
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2185e-04 - val_loss: 5.7252e-04
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8379e-04 - val_loss: 5.8635e-04
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8016e-04 - val_loss: 5.5847e-04
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3173e-04 - val_loss: 5.6837e-04
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8827e-04 - val_loss: 7.6514e-04
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0455e-04 - val_loss: 5.6235e-04
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8397e-04 - val_loss: 6.0859e-04
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6751e-04 - val_loss: 9.1757e-04
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7192e-04 - val_loss: 5.5173e-04
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2083e-04 - val_loss: 5.8944e-04
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7499e-04 - val_loss: 5.8571e-04
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6572e-04 - val_loss: 6.0980e-04
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5435e-04 - val_loss: 6.1053e-04
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7085e-04 - val_loss: 5.4726e-04
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5924e-04 - val_loss: 5.5625e-04
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7212e-04 - val_loss: 7.0674e-04
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9897e-04 - val_loss: 5.5422e-04
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8871e-04 - val_loss: 6.1343e-04
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0262e-04 - val_loss: 0.0014
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2670e-04 - val_loss: 0.0017
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0121e-04 - val_loss: 5.4480e-04
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9273e-04 - val_loss: 5.6423e-04
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1630e-04 - val_loss: 6.1280e-04

# %%
# Dự đoán
# train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

test_data = test_data[time_window:]

print(len(X_test))
print(len(y_test))
print(len(test_data))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 315
# 315
# 315

# %%
# Đánh giá mô hình
# train_predict = scaler.inverse_transform(train_predict.reshape(-1, 1))
test_predict = scaler.inverse_transform(test_predict.reshape(-1, 1))
# Reshape test_predict for compatibility with DataFrame creation
test_predict_reshaped = test_predict.reshape(-1, 1)

# Create a DataFrame with test_data index and test_predict values
predicted_test = pd.DataFrame(test_predict_reshaped, index=test_data.index, columns=["predicted_value"])

# %%
# Hàm dự đoán ngày tiếp theo
def predict_future(data, model, window_size, days):
    future_preds = []
    last_window = list(data[-window_size:])
    for _ in range(days):
        next_pred = model.predict(np.array(last_window).reshape(1, window_size))
        future_preds.append(next_pred[0, 0])  # Accessing the first element directly
        last_window.append(next_pred[0, 0])
        last_window.pop(0)
    return future_preds

# Dự đoán 90 ngày tiếp theo
days_to_predict = 90
future_predictions = predict_future(test_data['Close'].values, model, time_window, days_to_predict)

# Tạo các ngày tiếp theo
next_days_index = pd.date_range(start=test_data.index[-1] + pd.Timedelta(days=1), periods=days_to_predict)

# Tạo DataFrame cho các dự đoán tiếp theo
future_df = pd.DataFrame(future_predictions, index=next_days_index, columns=['Close Predict'])

train_data['Close'] = scaler.inverse_transform(train_data[['Close']])
test_data['Close'] = scaler.inverse_transform(test_data[['Close']])
future_df['Close Predict'] = scaler.inverse_transform(future_df[['Close Predict']])

print(future_df.head())
print(next_days_index)

# print(train_data.tail())
print(test_data.tail())
# print(predicted_test.head())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#             Close Predict
# 2024-06-01     168.303711
# 2024-06-02     164.865997
# 2024-06-03     161.597885
# 2024-06-04     160.117050
# 2024-06-05     157.475616
# DatetimeIndex(['2024-06-01', '2024-06-02', '2024-06-03', '2024-06-04',
#                '2024-06-05', '2024-06-06', '2024-06-07', '2024-06-08',
#                '2024-06-09', '2024-06-10', '2024-06-11', '2024-06-12',
#                '2024-06-13', '2024-06-14', '2024-06-15', '2024-06-16',
#                '2024-06-17', '2024-06-18', '2024-06-19', '2024-06-20',
#                '2024-06-21', '2024-06-22', '2024-06-23', '2024-06-24',
#                '2024-06-25', '2024-06-26', '2024-06-27', '2024-06-28',
#                '2024-06-29', '2024-06-30', '2024-07-01', '2024-07-02',
#                '2024-07-03', '2024-07-04', '2024-07-05', '2024-07-06',
#                '2024-07-07', '2024-07-08', '2024-07-09', '2024-07-10',
#                '2024-07-11', '2024-07-12', '2024-07-13', '2024-07-14',
#                '2024-07-15', '2024-07-16', '2024-07-17', '2024-07-18',
#                '2024-07-19', '2024-07-20', '2024-07-21', '2024-07-22',
#                '2024-07-23', '2024-07-24', '2024-07-25', '2024-07-26',
#                '2024-07-27', '2024-07-28', '2024-07-29', '2024-07-30',
#                '2024-07-31', '2024-08-01', '2024-08-02', '2024-08-03',
#                '2024-08-04', '2024-08-05', '2024-08-06', '2024-08-07',
#                '2024-08-08', '2024-08-09', '2024-08-10', '2024-08-11',
#                '2024-08-12', '2024-08-13', '2024-08-14', '2024-08-15',
#                '2024-08-16', '2024-08-17', '2024-08-18', '2024-08-19',
#                '2024-08-20', '2024-08-21', '2024-08-22', '2024-08-23',
#                '2024-08-24', '2024-08-25', '2024-08-26', '2024-08-27',
#                '2024-08-28', '2024-08-29'],
#               dtype='datetime64[ns]', freq='D')
#                  Close
# Date
# 2024-05-24  176.330002
# 2024-05-28  178.020004
# 2024-05-29  177.399994
# 2024-05-30  173.559998
# 2024-05-31  173.960007
# C:\Users\GIAHUY\AppData\Local\Temp\ipykernel_14992\2781551278.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Close'] = scaler.inverse_transform(train_data[['Close']])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Đánh giá MAE
mae = mean_absolute_error(test_data['Close'], predicted_test['predicted_value'])
print("Mean Absolute Error (MAE):", mae)

# Đánh giá MSE
mse = mean_squared_error(test_data['Close'], predicted_test['predicted_value'])
print("Mean Squared Error (MSE):", mse)

# Đánh giá RMSE
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Đánh giá MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(test_data['Close'], predicted_test['predicted_value'])
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Error (MAE): 4.225633452295696
# Mean Squared Error (MSE): 25.058037554129534
# Root Mean Squared Error (RMSE): 5.0058003909594255
# Mean Absolute Percentage Error (MAPE): 3.056076930075441

# %%
# Thêm phần tử cuối của train_data vào đầu của test_data và df_predicted
last_train_data = train_data.iloc[-1]
test_data = pd.concat([pd.DataFrame(last_train_data).T, test_data])
predicted_test = pd.concat([pd.DataFrame(last_train_data['Close'], index=[test_data.index[0] - pd.Timedelta(days=1)], columns=["predicted_value"]), predicted_test])

# Tạo 3 phần dữ liệu cho 90 ngày tiếp theo
future_df_1 = future_df[:30]
future_df_2 = future_df[30:60]
future_df_3 = future_df[60:]

# Vẽ biểu đồ dự đoán và thực tế
plt.figure(figsize=(20, 12))
plt.plot(train_data.index, train_data, label='Actual Train', color='blue')
plt.plot(test_data.index, test_data, label='Actual Test', color='red')
plt.plot(predicted_test.index, predicted_test, label='Predicted Test', color='orange')
plt.plot(future_df_1.index, future_df_1, label='Predicted Day 1-30', color='green')
plt.plot(future_df_2.index, future_df_2, label='Predicted Day 31-60', color='purple')
plt.plot(future_df_3.index, future_df_3, label='Predicted Day 61-90', color='yellow')
plt.legend()
plt.show()
