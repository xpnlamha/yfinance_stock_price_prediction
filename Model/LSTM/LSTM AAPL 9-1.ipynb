# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('D:/IS403_O21_HTCL_15/Dataset/AAPL.csv')
df1 = df.reset_index()['Close']

# Chọn cột 'Close' và cột 'Date'
df = df[['Date', 'Close']]

# Chuyển đổi cột 'Date' thành định dạng datetime
df['Date'] = pd.to_datetime(df['Date'])

# Thiết lập cột 'Date' làm chỉ mục
df.set_index('Date', inplace=True)

# 3. Scaler data
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# 4. Chia train test
train_size = int(0.9 * len(df1))
test_size = int(0.1 * len(df1))

train_data = df1[0:train_size]
test_data = df1[train_size:len(df1)]

time_step = 100
#Lấy thêm time_window ngày từ tập train vào tập test để dự đoán ngày đầu tiên của tập test
test_data = np.concatenate((train_data[-time_step:], test_data))

# %%
# 5. Hàm Create Dataset
import numpy

def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step):
        a = dataset[i:(i + time_step), 0]   # i=0, X=0,1,2,3-----99   Y=100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.optimizers import Adam

# Define LSTM Model
model = Sequential()
model.add(LSTM(100, return_sequences=True, input_shape=(time_step, 1)))  # Adjusting input_shape according to window size
model.add(LSTM(50))  # Second LSTM layer without return_sequences to reduce complexity
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1)
# Out:
# c:\Users\GIAHUY\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - loss: 0.0714 - val_loss: 0.0013
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - loss: 9.6601e-04 - val_loss: 0.0012
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 8.7024e-04 - val_loss: 0.0015
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 9.0014e-04 - val_loss: 0.0010
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - loss: 8.9535e-04 - val_loss: 0.0011
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 7.6581e-04 - val_loss: 0.0016
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 8.6293e-04 - val_loss: 0.0015
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 7.7442e-04 - val_loss: 8.6669e-04
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - loss: 7.9243e-04 - val_loss: 0.0014
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 7.6499e-04 - val_loss: 0.0020
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - loss: 6.7234e-04 - val_loss: 9.7115e-04
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 6.7078e-04 - val_loss: 8.3177e-04
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - loss: 7.0815e-04 - val_loss: 6.9690e-04
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 154ms/step - loss: 5.4929e-04 - val_loss: 0.0011
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 7.8588e-04 - val_loss: 8.1808e-04
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - loss: 5.9740e-04 - val_loss: 0.0010
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - loss: 6.0058e-04 - val_loss: 5.7182e-04
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - loss: 6.2936e-04 - val_loss: 9.0787e-04
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - loss: 5.2875e-04 - val_loss: 9.3172e-04
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - loss: 4.8017e-04 - val_loss: 5.9533e-04
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - loss: 4.4204e-04 - val_loss: 4.8629e-04
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 4.2426e-04 - val_loss: 6.1886e-04
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - loss: 4.8355e-04 - val_loss: 5.7844e-04
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - loss: 3.8618e-04 - val_loss: 4.1030e-04
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - loss: 4.0994e-04 - val_loss: 5.4043e-04
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - loss: 4.1714e-04 - val_loss: 7.9274e-04
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - loss: 3.8149e-04 - val_loss: 6.6881e-04
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - loss: 4.0560e-04 - val_loss: 8.8737e-04
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 4.4888e-04 - val_loss: 6.1685e-04
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 4.3273e-04 - val_loss: 3.7556e-04
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - loss: 3.4755e-04 - val_loss: 6.2061e-04
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - loss: 3.8649e-04 - val_loss: 8.1432e-04
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - loss: 4.1069e-04 - val_loss: 3.8538e-04
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - loss: 3.2932e-04 - val_loss: 3.0970e-04
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - loss: 3.1520e-04 - val_loss: 4.7824e-04
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - loss: 3.1728e-04 - val_loss: 3.6457e-04
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - loss: 3.4199e-04 - val_loss: 2.8738e-04
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - loss: 3.0315e-04 - val_loss: 4.6095e-04
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - loss: 2.8576e-04 - val_loss: 6.7728e-04
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 3.0535e-04 - val_loss: 8.0727e-04
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 3.4726e-04 - val_loss: 3.4210e-04
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - loss: 3.3618e-04 - val_loss: 2.6224e-04
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 3.4747e-04 - val_loss: 9.9001e-04
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 3.4384e-04 - val_loss: 2.5374e-04
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 3.7584e-04 - val_loss: 2.8225e-04
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - loss: 2.7987e-04 - val_loss: 3.2344e-04
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - loss: 2.7471e-04 - val_loss: 2.5822e-04
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - loss: 3.0397e-04 - val_loss: 2.6661e-04
# Epoch 52/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 2.4522e-04 - val_loss: 7.9859e-04
# Epoch 53/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 5.8547e-04 - val_loss: 5.3836e-04
# Epoch 54/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 2.9789e-04 - val_loss: 4.0311e-04
# Epoch 55/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - loss: 2.6702e-04 - val_loss: 2.3697e-04
# Epoch 56/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 2.4970e-04 - val_loss: 3.2244e-04
# Epoch 57/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 2.6662e-04 - val_loss: 3.3559e-04
# Epoch 58/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 111ms/step - loss: 2.2117e-04 - val_loss: 2.3194e-04
# Epoch 59/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 2.7642e-04 - val_loss: 2.2693e-04
# Epoch 60/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - loss: 2.4457e-04 - val_loss: 2.6462e-04
# Epoch 61/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 2.5909e-04 - val_loss: 2.5080e-04
# Epoch 62/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 2.4366e-04 - val_loss: 4.8189e-04
# Epoch 63/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 2.7133e-04 - val_loss: 2.8281e-04
# Epoch 64/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - loss: 2.5386e-04 - val_loss: 2.1557e-04
# Epoch 65/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - loss: 3.0260e-04 - val_loss: 2.1446e-04
# Epoch 66/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - loss: 2.4546e-04 - val_loss: 3.3947e-04
# Epoch 67/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - loss: 2.4801e-04 - val_loss: 2.1391e-04
# Epoch 68/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - loss: 2.7747e-04 - val_loss: 2.2249e-04
# Epoch 69/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - loss: 2.6093e-04 - val_loss: 2.1159e-04
# Epoch 70/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - loss: 2.2305e-04 - val_loss: 2.3558e-04
# Epoch 71/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 3.4040e-04 - val_loss: 4.1974e-04
# Epoch 72/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 2.9203e-04 - val_loss: 7.3683e-04
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - loss: 3.2003e-04 - val_loss: 2.4280e-04
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 2.2750e-04 - val_loss: 2.2986e-04
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 2.1833e-04 - val_loss: 2.9214e-04
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 2.3459e-04 - val_loss: 4.3143e-04
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 2.8951e-04 - val_loss: 2.0649e-04
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - loss: 2.9193e-04 - val_loss: 2.1511e-04
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - loss: 2.1908e-04 - val_loss: 2.2756e-04
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - loss: 2.3994e-04 - val_loss: 4.0753e-04
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 2.3936e-04 - val_loss: 2.0654e-04
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 190ms/step - loss: 3.2334e-04 - val_loss: 2.0661e-04
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 201ms/step - loss: 2.4036e-04 - val_loss: 6.4994e-04
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 222ms/step - loss: 3.2803e-04 - val_loss: 2.0728e-04
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - loss: 2.1580e-04 - val_loss: 2.6966e-04
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 257ms/step - loss: 2.2720e-04 - val_loss: 6.6206e-04
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 226ms/step - loss: 2.8387e-04 - val_loss: 3.8518e-04
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 267ms/step - loss: 2.2134e-04 - val_loss: 2.0313e-04
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - loss: 2.5935e-04 - val_loss: 6.5595e-04
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 13s 293ms/step - loss: 3.4073e-04 - val_loss: 2.2766e-04
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - loss: 2.2642e-04 - val_loss: 3.7091e-04
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 268ms/step - loss: 2.4133e-04 - val_loss: 4.5405e-04
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 283ms/step - loss: 2.2928e-04 - val_loss: 2.4681e-04
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 13s 308ms/step - loss: 2.4981e-04 - val_loss: 2.2376e-04
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - loss: 2.4308e-04 - val_loss: 2.5121e-04
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 14s 293ms/step - loss: 2.4788e-04 - val_loss: 2.3129e-04
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - loss: 2.6610e-04 - val_loss: 3.2211e-04
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - loss: 2.2565e-04 - val_loss: 2.7119e-04
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 257ms/step - loss: 2.5815e-04 - val_loss: 2.3886e-04
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 227ms/step - loss: 2.3220e-04 - val_loss: 5.0882e-04

# %%
# 10. Dự báo dữ liệu test
y_pred = model.predict(X_test)

# 13. Dự báo 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
x_input = x_input.reshape((1, time_step, 1))

temp_input = x_input[0].tolist()
temp_input = temp_input[0]
days_to_predict = 90
lst_output = []
n_steps = 100
i = 0
while(i < days_to_predict):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i + 1

test_data = test_data[time_step:]
lst_output.insert(0, test_data[-1])
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step

# %%
train_data = scaler.inverse_transform(train_data)
test_data = scaler.inverse_transform(test_data)
y_pred = scaler.inverse_transform(y_pred)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Đánh giá MAE
mae = mean_absolute_error(test_data, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Đánh giá MSE
mse = mean_squared_error(test_data, y_pred)
print("Mean Squared Error (MSE):", mse)

# Đánh giá RMSE
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Đánh giá MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(test_data, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Error (MAE): 3.0898692429724592
# Mean Squared Error (MSE): 13.446492342316594
# Root Mean Squared Error (RMSE): 3.666945914833841
# Mean Absolute Percentage Error (MAPE): 1.6870994104673673

# %%
# 14. Vẽ hình
plt.figure(figsize=(20, 12))

# train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
train_data_index = df[0:train_size].index
plt.plot(train_data_index, train_data)

test_data_index = df[train_size:len(df)].index
plt.plot(test_data_index, test_data)

plt.plot(test_data_index, y_pred)



next_30days_index = pd.date_range(start=df.index[-2] + pd.Timedelta(days=1), periods=31)
next_60days_index = pd.date_range(next_30days_index[-1] + pd.Timedelta(days=1), periods=30)
next_90days_index = pd.date_range(next_60days_index[-1] + pd.Timedelta(days=1), periods=30)

plt.plot(next_30days_index, scaler.inverse_transform(lst_output)[:31])

plt.plot(next_60days_index, scaler.inverse_transform(lst_output)[31:61])

plt.plot(next_90days_index, scaler.inverse_transform(lst_output)[61:])

plt.legend(['Train', 'Test', 'Predict', 'Predict Day 1-30', 'Predicted Day 31-60', 'Predicted Day 61-90'])
plt.show()
print(len(test_data))
print(len(y_pred))

print(len(train_data))
# Out:
# 158
# 158
# 1416
