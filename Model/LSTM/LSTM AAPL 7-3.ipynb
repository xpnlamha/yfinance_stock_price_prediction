# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('D:/IS403_O21_HTCL_15/Dataset/AAPL.csv')
df1 = df.reset_index()['Close']

# Chọn cột 'Close' và cột 'Date'
df = df[['Date', 'Close']]

# Chuyển đổi cột 'Date' thành định dạng datetime
df['Date'] = pd.to_datetime(df['Date'])

# Thiết lập cột 'Date' làm chỉ mục
df.set_index('Date', inplace=True)

# 3. Scaler data
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[0:train_size]
test_data = df1[train_size:len(df1)]

time_step = 100
#Lấy thêm time_window ngày từ tập train vào tập test để dự đoán ngày đầu tiên của tập test
test_data = np.concatenate((train_data[-time_step:], test_data))

# %%
# 5. Hàm Create Dataset
import numpy

def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step):
        a = dataset[i:(i + time_step), 0]   # i=0, X=0,1,2,3-----99   Y=100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.optimizers import Adam

# Define LSTM Model
model = Sequential()
model.add(LSTM(100, return_sequences=True, input_shape=(time_step, 1)))  # Adjusting input_shape according to window size
model.add(LSTM(50))  # Second LSTM layer without return_sequences to reduce complexity
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# c:\Users\GIAHUY\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 0.0646 - val_loss: 0.0025
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 9.6857e-04 - val_loss: 0.0019
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 8.3556e-04 - val_loss: 0.0017
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 8.6721e-04 - val_loss: 0.0014
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 8.4225e-04 - val_loss: 0.0013
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 7.4595e-04 - val_loss: 0.0012
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 7.2515e-04 - val_loss: 0.0011
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 7.5228e-04 - val_loss: 0.0014
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 7.1673e-04 - val_loss: 0.0012
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 6.2655e-04 - val_loss: 0.0011
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - loss: 6.5441e-04 - val_loss: 0.0016
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 6.3037e-04 - val_loss: 9.8101e-04
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 6.1290e-04 - val_loss: 0.0012
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 6.5385e-04 - val_loss: 9.7750e-04
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 5.6198e-04 - val_loss: 0.0018
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 6.5835e-04 - val_loss: 8.6073e-04
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 7.4892e-04 - val_loss: 8.7092e-04
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 6.0885e-04 - val_loss: 0.0011
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.7194e-04 - val_loss: 0.0012
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 6.0658e-04 - val_loss: 9.6729e-04
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 5.5588e-04 - val_loss: 0.0012
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 6.6799e-04 - val_loss: 7.9997e-04
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 5.6567e-04 - val_loss: 9.8059e-04
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 5.8042e-04 - val_loss: 7.2242e-04
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 5.2478e-04 - val_loss: 8.0419e-04
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 5.5386e-04 - val_loss: 6.8988e-04
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 6.2227e-04 - val_loss: 6.8550e-04
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 4.9827e-04 - val_loss: 8.9088e-04
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 4.9491e-04 - val_loss: 7.0436e-04
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 4.9632e-04 - val_loss: 0.0011
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 5.6232e-04 - val_loss: 6.3337e-04
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 4.7253e-04 - val_loss: 0.0011
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 4.6337e-04 - val_loss: 9.8284e-04
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 4.4534e-04 - val_loss: 0.0014
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 4.6670e-04 - val_loss: 0.0011
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 4.7905e-04 - val_loss: 0.0010
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 6.1127e-04 - val_loss: 5.9683e-04
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 4.2560e-04 - val_loss: 0.0014
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 4.6259e-04 - val_loss: 5.6078e-04
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 4.0710e-04 - val_loss: 5.3762e-04
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 4.2566e-04 - val_loss: 6.1934e-04
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - loss: 4.0904e-04 - val_loss: 7.8745e-04
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - loss: 3.6706e-04 - val_loss: 0.0013
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - loss: 4.6194e-04 - val_loss: 8.8270e-04
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 4.7627e-04 - val_loss: 6.6246e-04
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - loss: 3.7970e-04 - val_loss: 5.5039e-04
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - loss: 3.5777e-04 - val_loss: 5.1717e-04
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 3.4658e-04 - val_loss: 6.5955e-04
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - loss: 5.4743e-04 - val_loss: 5.0370e-04
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 3.7813e-04 - val_loss: 6.8871e-04
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - loss: 3.4222e-04 - val_loss: 5.8113e-04
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - loss: 3.6016e-04 - val_loss: 7.0005e-04
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 4.3343e-04 - val_loss: 9.3258e-04
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 3.5478e-04 - val_loss: 4.7221e-04
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - loss: 4.1380e-04 - val_loss: 4.5064e-04
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - loss: 3.8398e-04 - val_loss: 4.3780e-04
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - loss: 3.3129e-04 - val_loss: 4.3138e-04
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - loss: 3.4026e-04 - val_loss: 4.5460e-04
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - loss: 3.6417e-04 - val_loss: 0.0016
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 3.9307e-04 - val_loss: 5.0305e-04
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - loss: 3.3093e-04 - val_loss: 4.4069e-04
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 3.0018e-04 - val_loss: 4.4830e-04
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 2.9583e-04 - val_loss: 4.8037e-04
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step - loss: 3.1688e-04 - val_loss: 4.5066e-04
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - loss: 3.3989e-04 - val_loss: 4.6587e-04
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - loss: 3.0444e-04 - val_loss: 4.6358e-04
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 2.8644e-04 - val_loss: 4.8662e-04
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - loss: 3.0695e-04 - val_loss: 3.8045e-04
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 2.6538e-04 - val_loss: 3.7680e-04
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - loss: 2.7865e-04 - val_loss: 6.2491e-04
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - loss: 3.0568e-04 - val_loss: 4.0554e-04
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 3.1704e-04 - val_loss: 4.5870e-04
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - loss: 2.9686e-04 - val_loss: 3.7881e-04
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - loss: 3.1957e-04 - val_loss: 3.5736e-04
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 2.7477e-04 - val_loss: 7.1417e-04
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - loss: 2.8055e-04 - val_loss: 9.9381e-04
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - loss: 3.5147e-04 - val_loss: 5.8048e-04
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - loss: 2.9784e-04 - val_loss: 3.8476e-04
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 2.6673e-04 - val_loss: 3.4629e-04
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 164ms/step - loss: 2.5791e-04 - val_loss: 3.8242e-04
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 165ms/step - loss: 2.2122e-04 - val_loss: 3.5657e-04
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - loss: 2.4679e-04 - val_loss: 3.6194e-04
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - loss: 2.4602e-04 - val_loss: 4.0300e-04
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 2.5842e-04 - val_loss: 8.8475e-04
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 3.1988e-04 - val_loss: 3.2113e-04
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 2.5576e-04 - val_loss: 3.1386e-04
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - loss: 2.4469e-04 - val_loss: 4.4318e-04
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - loss: 2.3577e-04 - val_loss: 3.2262e-04
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - loss: 2.8294e-04 - val_loss: 3.1067e-04
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.9094e-04 - val_loss: 3.9322e-04
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 2.7646e-04 - val_loss: 6.4389e-04
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 2.5199e-04 - val_loss: 6.5084e-04
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 2.5283e-04 - val_loss: 3.8378e-04
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - loss: 3.1336e-04 - val_loss: 5.6075e-04
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 2.4541e-04 - val_loss: 5.8928e-04
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 2.4084e-04 - val_loss: 2.8603e-04
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 2.3193e-04 - val_loss: 3.3511e-04
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - loss: 2.1784e-04 - val_loss: 4.8204e-04
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - loss: 2.5288e-04 - val_loss: 3.5019e-04

# %%
# 10. Dự báo dữ liệu test
y_pred = model.predict(X_test)

# 13. Dự báo 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
x_input = x_input.reshape((1, time_step, 1))

temp_input = x_input[0].tolist()
temp_input = temp_input[0]
days_to_predict = 90
lst_output = []
n_steps = 100
i = 0
while(i < days_to_predict):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i + 1

test_data = test_data[time_step:]
lst_output.insert(0, test_data[-1])
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step

# %%
train_data = scaler.inverse_transform(train_data)
test_data = scaler.inverse_transform(test_data)
y_pred = scaler.inverse_transform(y_pred)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Đánh giá MAE
mae = mean_absolute_error(test_data, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Đánh giá MSE
mse = mean_squared_error(test_data, y_pred)
print("Mean Squared Error (MSE):", mse)

# Đánh giá RMSE
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Đánh giá MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(test_data, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Error (MAE): 2.410680768160346
# Mean Squared Error (MSE): 9.25422974126329
# Root Mean Squared Error (RMSE): 3.042076550855236
# Mean Absolute Percentage Error (MAPE): 1.4466011764314346

# %%
# 14. Vẽ hình
plt.figure(figsize=(20, 12))

# train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
train_data_index = df[0:train_size].index
plt.plot(train_data_index, train_data)

test_data_index = df[train_size:len(df)].index
plt.plot(test_data_index, test_data)

plt.plot(test_data_index, y_pred)



next_30days_index = pd.date_range(start=df.index[-2] + pd.Timedelta(days=1), periods=31)
next_60days_index = pd.date_range(next_30days_index[-1] + pd.Timedelta(days=1), periods=30)
next_90days_index = pd.date_range(next_60days_index[-1] + pd.Timedelta(days=1), periods=30)

plt.plot(next_30days_index, scaler.inverse_transform(lst_output)[:31])

plt.plot(next_60days_index, scaler.inverse_transform(lst_output)[31:61])

plt.plot(next_90days_index, scaler.inverse_transform(lst_output)[61:])

plt.legend(['Train', 'Test', 'Predict', 'Predict Day 1-30', 'Predicted Day 31-60', 'Predicted Day 61-90'])
plt.show()
print(len(test_data))
print(len(y_pred))

print(len(train_data))
# Out:
# 473
# 473
# 1101
