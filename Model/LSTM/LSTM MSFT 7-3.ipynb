# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('D:/IS403_O21_HTCL_15/Dataset/MSFT.csv')
df1 = df.reset_index()['Close']

# Chọn cột 'Close' và cột 'Date'
df = df[['Date', 'Close']]

# Chuyển đổi cột 'Date' thành định dạng datetime
df['Date'] = pd.to_datetime(df['Date'])

# Thiết lập cột 'Date' làm chỉ mục
df.set_index('Date', inplace=True)

# 3. Scaler data
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[0:train_size]
test_data = df1[train_size:len(df1)]

time_step = 100
#Lấy thêm time_window ngày từ tập train vào tập test để dự đoán ngày đầu tiên của tập test
test_data = np.concatenate((train_data[-time_step:], test_data))

# %%
# 5. Hàm Create Dataset
import numpy

def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step):
        a = dataset[i:(i + time_step), 0]   # i=0, X=0,1,2,3-----99   Y=100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.optimizers import Adam

# Define LSTM Model
model = Sequential()
model.add(LSTM(100, return_sequences=True, input_shape=(time_step, 1)))  # Adjusting input_shape according to window size
model.add(LSTM(50))  # Second LSTM layer without return_sequences to reduce complexity
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1)
# Out:
# c:\Users\GIAHUY\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 58s 602ms/step - loss: 0.0336 - val_loss: 0.0061
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 254ms/step - loss: 9.9368e-04 - val_loss: 0.0016
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 249ms/step - loss: 4.9304e-04 - val_loss: 0.0016
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 301ms/step - loss: 5.1875e-04 - val_loss: 0.0015
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 305ms/step - loss: 5.1609e-04 - val_loss: 0.0014
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 290ms/step - loss: 4.7489e-04 - val_loss: 0.0010
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 332ms/step - loss: 5.7881e-04 - val_loss: 0.0012
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 323ms/step - loss: 4.8712e-04 - val_loss: 9.4156e-04
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 290ms/step - loss: 5.1429e-04 - val_loss: 9.1342e-04
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 385ms/step - loss: 4.1568e-04 - val_loss: 0.0020
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 348ms/step - loss: 4.5949e-04 - val_loss: 0.0013
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 270ms/step - loss: 4.7046e-04 - val_loss: 0.0013
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - loss: 3.9849e-04 - val_loss: 9.9788e-04
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 333ms/step - loss: 4.3222e-04 - val_loss: 7.9973e-04
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 304ms/step - loss: 3.9785e-04 - val_loss: 8.8551e-04
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 305ms/step - loss: 4.9411e-04 - val_loss: 0.0020
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 333ms/step - loss: 4.1991e-04 - val_loss: 0.0013
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 3.7569e-04 - val_loss: 0.0011
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 308ms/step - loss: 3.8694e-04 - val_loss: 6.1045e-04
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 246ms/step - loss: 3.3297e-04 - val_loss: 5.4801e-04
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 273ms/step - loss: 3.2909e-04 - val_loss: 7.9245e-04
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 279ms/step - loss: 3.1439e-04 - val_loss: 7.4653e-04
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 270ms/step - loss: 3.1659e-04 - val_loss: 5.8747e-04
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 275ms/step - loss: 3.2703e-04 - val_loss: 7.0960e-04
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 3.0781e-04 - val_loss: 5.0930e-04
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 284ms/step - loss: 3.6688e-04 - val_loss: 9.3915e-04
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 270ms/step - loss: 3.1508e-04 - val_loss: 4.7108e-04
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 234ms/step - loss: 2.5545e-04 - val_loss: 5.0900e-04
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 242ms/step - loss: 2.9636e-04 - val_loss: 6.5896e-04
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - loss: 2.8771e-04 - val_loss: 4.6331e-04
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - loss: 2.7090e-04 - val_loss: 5.2678e-04
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - loss: 3.0724e-04 - val_loss: 9.7613e-04
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - loss: 2.7217e-04 - val_loss: 5.4641e-04
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 303ms/step - loss: 2.7841e-04 - val_loss: 6.8049e-04
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - loss: 2.9841e-04 - val_loss: 4.1817e-04
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 262ms/step - loss: 2.9508e-04 - val_loss: 4.7388e-04
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 253ms/step - loss: 2.4009e-04 - val_loss: 4.0153e-04
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 228ms/step
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 253ms/step - loss: 1.6598e-04 - val_loss: 3.8984e-04
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 264ms/step - loss: 1.4920e-04 - val_loss: 2.6379e-04
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 259ms/step - loss: 1.4860e-04 - val_loss: 2.7294e-04
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 248ms/step - loss: 1.8470e-04 - val_loss: 3.2532e-04
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step - loss: 1.4160e-04 - val_loss: 6.6402e-04
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 295ms/step - loss: 2.1904e-04 - val_loss: 7.9193e-04
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step - loss: 1.6348e-04 - val_loss: 3.1291e-04
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 272ms/step - loss: 1.6237e-04 - val_loss: 3.7758e-04
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - loss: 1.4352e-04 - val_loss: 2.5757e-04
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 270ms/step - loss: 1.4748e-04 - val_loss: 2.6908e-04
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 225ms/step - loss: 1.5149e-04 - val_loss: 2.7801e-04
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 232ms/step - loss: 1.6593e-04 - val_loss: 6.6792e-04
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 253ms/step - loss: 2.0067e-04 - val_loss: 5.1086e-04
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - loss: 1.8791e-04 - val_loss: 8.7006e-04
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 188ms/step - loss: 1.7624e-04 - val_loss: 2.5061e-04
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 265ms/step - loss: 1.4840e-04 - val_loss: 2.6629e-04
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 242ms/step - loss: 1.3216e-04 - val_loss: 3.6662e-04
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 250ms/step - loss: 1.3931e-04 - val_loss: 4.0338e-04
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step - loss: 1.5183e-04 - val_loss: 2.7382e-04
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 236ms/step - loss: 1.3735e-04 - val_loss: 2.8587e-04

# %%
# 10. Dự báo dữ liệu test
y_pred = model.predict(X_test)

# 13. Dự báo 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
x_input = x_input.reshape((1, time_step, 1))

temp_input = x_input[0].tolist()
temp_input = temp_input[0]
days_to_predict = 90
lst_output = []
n_steps = 100
i = 0
while(i < days_to_predict):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i + 1

test_data = test_data[time_step:]
lst_output.insert(0, test_data[-1])
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 410ms/step

# %%
train_data = scaler.inverse_transform(train_data)
test_data = scaler.inverse_transform(test_data)
y_pred = scaler.inverse_transform(y_pred)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Đánh giá MAE
mae = mean_absolute_error(test_data, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Đánh giá MSE
mse = mean_squared_error(test_data, y_pred)
print("Mean Squared Error (MSE):", mse)

# Đánh giá RMSE
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Đánh giá MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(test_data, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Error (MAE): 4.608282647308154
# Mean Squared Error (MSE): 33.69875456687453
# Root Mean Squared Error (RMSE): 5.805062839183959
# Mean Absolute Percentage Error (MAPE): 1.4739790565014392

# %%
# 14. Vẽ hình
plt.figure(figsize=(20, 12))

# train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
train_data_index = df[0:train_size].index
plt.plot(train_data_index, train_data)

test_data_index = df[train_size:len(df)].index
plt.plot(test_data_index, test_data)

plt.plot(test_data_index, y_pred)



next_30days_index = pd.date_range(start=df.index[-2] + pd.Timedelta(days=1), periods=31)
next_60days_index = pd.date_range(next_30days_index[-1] + pd.Timedelta(days=1), periods=30)
next_90days_index = pd.date_range(next_60days_index[-1] + pd.Timedelta(days=1), periods=30)

plt.plot(next_30days_index, scaler.inverse_transform(lst_output)[:31])

plt.plot(next_60days_index, scaler.inverse_transform(lst_output)[31:61])

plt.plot(next_90days_index, scaler.inverse_transform(lst_output)[61:])

plt.legend(['Train', 'Test', 'Predict', 'Predict Day 1-30', 'Predicted Day 31-60', 'Predicted Day 61-90'])
plt.show()
print(len(test_data))
print(len(y_pred))

print(len(train_data))
# Out:
# 473
# 473
# 1101
