# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('D:/IS403_O21_HTCL_15/Dataset/GOOG.csv')
df1 = df.reset_index()['Close']

# Chọn cột 'Close' và cột 'Date'
df = df[['Date', 'Close']]

# Chuyển đổi cột 'Date' thành định dạng datetime
df['Date'] = pd.to_datetime(df['Date'])

# Thiết lập cột 'Date' làm chỉ mục
df.set_index('Date', inplace=True)

# 3. Scaler data
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[0:train_size]
test_data = df1[train_size:len(df1)]

time_step = 100
#Lấy thêm time_window ngày từ tập train vào tập test để dự đoán ngày đầu tiên của tập test
test_data = np.concatenate((train_data[-time_step:], test_data))

# %%
# 5. Hàm Create Dataset
import numpy

def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step):
        a = dataset[i:(i + time_step), 0]   # i=0, X=0,1,2,3-----99   Y=100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.optimizers import Adam

# Define LSTM Model
model = Sequential()
model.add(LSTM(100, return_sequences=True, input_shape=(time_step, 1)))  # Adjusting input_shape according to window size
model.add(LSTM(50))  # Second LSTM layer without return_sequences to reduce complexity
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1)
# Out:
# c:\Users\GIAHUY\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 26s 254ms/step - loss: 0.0488 - val_loss: 0.0027
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 7.6727e-04 - val_loss: 0.0017
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - loss: 6.9255e-04 - val_loss: 0.0018
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - loss: 7.1925e-04 - val_loss: 0.0017
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 6.9155e-04 - val_loss: 0.0016
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 254ms/step - loss: 6.3986e-04 - val_loss: 0.0017
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 259ms/step - loss: 6.2081e-04 - val_loss: 0.0018
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 240ms/step - loss: 6.9105e-04 - val_loss: 0.0015
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - loss: 6.3545e-04 - val_loss: 0.0015
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step - loss: 6.5355e-04 - val_loss: 0.0013
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 288ms/step - loss: 6.4333e-04 - val_loss: 0.0013
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 312ms/step - loss: 5.4501e-04 - val_loss: 0.0016
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 293ms/step - loss: 6.4662e-04 - val_loss: 0.0012
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 291ms/step - loss: 5.0462e-04 - val_loss: 0.0012
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 320ms/step - loss: 4.9904e-04 - val_loss: 0.0012
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 286ms/step - loss: 4.9243e-04 - val_loss: 0.0016
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 295ms/step - loss: 5.2748e-04 - val_loss: 0.0017
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 305ms/step - loss: 6.7581e-04 - val_loss: 0.0015
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 362ms/step - loss: 4.7577e-04 - val_loss: 0.0011
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 275ms/step - loss: 4.7513e-04 - val_loss: 0.0010
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 301ms/step - loss: 5.4362e-04 - val_loss: 0.0010
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step - loss: 4.4680e-04 - val_loss: 0.0015
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 301ms/step - loss: 5.5888e-04 - val_loss: 0.0011
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 267ms/step - loss: 5.0486e-04 - val_loss: 0.0012
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 286ms/step - loss: 4.5342e-04 - val_loss: 9.2706e-04
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 264ms/step - loss: 4.2980e-04 - val_loss: 9.0653e-04
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 269ms/step - loss: 4.0704e-04 - val_loss: 8.5191e-04
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - loss: 4.5655e-04 - val_loss: 0.0012
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 272ms/step - loss: 5.5110e-04 - val_loss: 8.8362e-04
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 288ms/step - loss: 4.0534e-04 - val_loss: 7.7735e-04
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 277ms/step - loss: 3.8285e-04 - val_loss: 0.0011
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 286ms/step - loss: 4.5947e-04 - val_loss: 8.5229e-04
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step - loss: 4.0373e-04 - val_loss: 8.0183e-04
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 252ms/step - loss: 4.6133e-04 - val_loss: 8.1525e-04
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 277ms/step - loss: 3.8985e-04 - val_loss: 7.2260e-04
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 276ms/step - loss: 4.0123e-04 - val_loss: 6.9963e-04
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - loss: 4.3661e-04 - val_loss: 6.8332e-04
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 277ms/step - loss: 3.5618e-04 - val_loss: 6.7347e-04
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - loss: 3.8338e-04 - val_loss: 7.0002e-04
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 283ms/step - loss: 2.9550e-04 - val_loss: 6.7267e-04
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - loss: 3.1252e-04 - val_loss: 7.8394e-04
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - loss: 3.1825e-04 - val_loss: 6.1315e-04
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 254ms/step - loss: 3.5114e-04 - val_loss: 0.0011
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - loss: 3.8853e-04 - val_loss: 7.6665e-04
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 305ms/step - loss: 3.2814e-04 - val_loss: 5.8150e-04
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 272ms/step - loss: 3.1267e-04 - val_loss: 5.6786e-04
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - loss: 3.0777e-04 - val_loss: 6.9160e-04
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - loss: 3.1138e-04 - val_loss: 6.0892e-04
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step - loss: 3.0985e-04 - val_loss: 6.3242e-04
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step - loss: 2.9474e-04 - val_loss: 9.3098e-04
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 272ms/step - loss: 2.9986e-04 - val_loss: 5.0562e-04
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - loss: 2.4726e-04 - val_loss: 5.3067e-04
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 307ms/step - loss: 2.7549e-04 - val_loss: 5.2942e-04
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step - loss: 2.5771e-04 - val_loss: 6.2388e-04
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 260ms/step - loss: 2.4102e-04 - val_loss: 4.8497e-04
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 249ms/step - loss: 2.4512e-04 - val_loss: 6.9360e-04
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 260ms/step - loss: 2.5303e-04 - val_loss: 4.6383e-04
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - loss: 2.1563e-04 - val_loss: 4.5491e-04
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - loss: 2.3669e-04 - val_loss: 4.8788e-04
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step - loss: 2.3530e-04 - val_loss: 6.5121e-04
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 256ms/step - loss: 2.5150e-04 - val_loss: 4.5171e-04
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - loss: 2.0744e-04 - val_loss: 4.3713e-04
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 241ms/step - loss: 2.3145e-04 - val_loss: 5.1719e-04
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 235ms/step - loss: 2.4797e-04 - val_loss: 4.3214e-04
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 233ms/step - loss: 2.2629e-04 - val_loss: 6.4554e-04
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 248ms/step - loss: 2.2455e-04 - val_loss: 5.9072e-04
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 253ms/step - loss: 2.6564e-04 - val_loss: 5.0916e-04
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 236ms/step - loss: 2.2240e-04 - val_loss: 4.2538e-04
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 209ms/step - loss: 2.1769e-04 - val_loss: 5.6533e-04
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - loss: 2.4936e-04 - val_loss: 4.2508e-04
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 258ms/step - loss: 1.9250e-04 - val_loss: 6.1950e-04
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 226ms/step - loss: 2.2794e-04 - val_loss: 4.1286e-04
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 258ms/step - loss: 2.1304e-04 - val_loss: 5.5984e-04
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 2.2907e-04 - val_loss: 5.3288e-04
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 261ms/step - loss: 2.5578e-04 - val_loss: 4.0495e-04
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - loss: 1.9354e-04 - val_loss: 6.0860e-04
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 256ms/step - loss: 2.0688e-04 - val_loss: 3.9832e-04
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step - loss: 1.9288e-04 - val_loss: 3.9956e-04
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - loss: 1.8873e-04 - val_loss: 5.9334e-04
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 263ms/step - loss: 2.0192e-04 - val_loss: 4.7499e-04
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 297ms/step - loss: 2.1158e-04 - val_loss: 5.8497e-04
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 244ms/step - loss: 2.3228e-04 - val_loss: 4.5576e-04
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 231ms/step - loss: 2.0971e-04 - val_loss: 3.9929e-04
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 281ms/step - loss: 2.3849e-04 - val_loss: 4.2930e-04
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 264ms/step - loss: 2.3205e-04 - val_loss: 4.1191e-04
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 257ms/step - loss: 1.9636e-04 - val_loss: 4.9770e-04
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step - loss: 2.1036e-04 - val_loss: 3.8430e-04
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 298ms/step - loss: 2.1746e-04 - val_loss: 5.2707e-04
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 267ms/step - loss: 2.5393e-04 - val_loss: 4.2419e-04
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 311ms/step - loss: 2.0387e-04 - val_loss: 3.8887e-04
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - loss: 2.0161e-04 - val_loss: 4.0561e-04
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - loss: 2.0067e-04 - val_loss: 4.1298e-04
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - loss: 1.9660e-04 - val_loss: 8.5738e-04
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 252ms/step - loss: 2.9290e-04 - val_loss: 3.9185e-04
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 263ms/step - loss: 1.7756e-04 - val_loss: 3.9605e-04
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 266ms/step - loss: 2.0859e-04 - val_loss: 9.1006e-04
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 269ms/step - loss: 2.4421e-04 - val_loss: 4.2115e-04
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 251ms/step - loss: 2.0107e-04 - val_loss: 4.8742e-04
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 241ms/step - loss: 2.3556e-04 - val_loss: 4.1966e-04

# %%
# 10. Dự báo dữ liệu test
y_pred = model.predict(X_test)

# 13. Dự báo 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
x_input = x_input.reshape((1, time_step, 1))

temp_input = x_input[0].tolist()
temp_input = temp_input[0]
days_to_predict = 90
lst_output = []
n_steps = 100
i = 0
while(i < days_to_predict):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i + 1

test_data = test_data[time_step:]
lst_output.insert(0, test_data[-1])
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 322ms/step

# %%
train_data = scaler.inverse_transform(train_data)
test_data = scaler.inverse_transform(test_data)
y_pred = scaler.inverse_transform(y_pred)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Đánh giá MAE
mae = mean_absolute_error(test_data, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Đánh giá MSE
mse = mean_squared_error(test_data, y_pred)
print("Mean Squared Error (MSE):", mse)

# Đánh giá RMSE
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Đánh giá MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(test_data, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Error (MAE): 1.987487430585607
# Mean Squared Error (MSE): 7.171990071885583
# Root Mean Squared Error (RMSE): 2.678057145000006
# Mean Absolute Percentage Error (MAPE): 1.6417808467594566

# %%
# 14. Vẽ hình
plt.figure(figsize=(20, 12))

# train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
train_data_index = df[0:train_size].index
plt.plot(train_data_index, train_data)

test_data_index = df[train_size:len(df)].index
plt.plot(test_data_index, test_data)

plt.plot(test_data_index, y_pred)



next_30days_index = pd.date_range(start=df.index[-2] + pd.Timedelta(days=1), periods=31)
next_60days_index = pd.date_range(next_30days_index[-1] + pd.Timedelta(days=1), periods=30)
next_90days_index = pd.date_range(next_60days_index[-1] + pd.Timedelta(days=1), periods=30)

plt.plot(next_30days_index, scaler.inverse_transform(lst_output)[:31])

plt.plot(next_60days_index, scaler.inverse_transform(lst_output)[31:61])

plt.plot(next_90days_index, scaler.inverse_transform(lst_output)[61:])

plt.legend(['Train', 'Test', 'Predict', 'Predict Day 1-30', 'Predicted Day 31-60', 'Predicted Day 61-90'])
plt.show()
print(len(test_data))
print(len(y_pred))

print(len(train_data))
# Out:
# 473
# 473
# 1101
