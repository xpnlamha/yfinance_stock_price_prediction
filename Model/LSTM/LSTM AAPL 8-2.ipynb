# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('D:/IS403_O21_HTCL_15/Dataset/AAPL.csv')
df1 = df.reset_index()['Close']

# Chọn cột 'Close' và cột 'Date'
df = df[['Date', 'Close']]

# Chuyển đổi cột 'Date' thành định dạng datetime
df['Date'] = pd.to_datetime(df['Date'])

# Thiết lập cột 'Date' làm chỉ mục
df.set_index('Date', inplace=True)

# 3. Scaler data
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = int(0.2 * len(df1))

train_data = df1[0:train_size]
test_data = df1[train_size:len(df1)]

time_step = 100
#Lấy thêm time_window ngày từ tập train vào tập test để dự đoán ngày đầu tiên của tập test
test_data = np.concatenate((train_data[-time_step:], test_data))

# %%
# 5. Hàm Create Dataset
import numpy

def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step):
        a = dataset[i:(i + time_step), 0]   # i=0, X=0,1,2,3-----99   Y=100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
from keras.optimizers import Adam

# Define LSTM Model
model = Sequential()
model.add(LSTM(100, return_sequences=True, input_shape=(time_step, 1)))  # Adjusting input_shape according to window size
model.add(LSTM(50))  # Second LSTM layer without return_sequences to reduce complexity
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=32, verbose=1)
# Out:
# c:\Users\GIAHUY\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 15s 184ms/step - loss: 0.0429 - val_loss: 0.0063
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - loss: 9.4734e-04 - val_loss: 0.0021
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - loss: 9.0253e-04 - val_loss: 0.0019
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 8.2660e-04 - val_loss: 0.0012
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - loss: 8.0223e-04 - val_loss: 9.6412e-04
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 8.4604e-04 - val_loss: 7.9245e-04
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 8.1532e-04 - val_loss: 0.0011
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - loss: 6.5160e-04 - val_loss: 0.0021
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - loss: 7.7908e-04 - val_loss: 0.0017
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - loss: 7.0431e-04 - val_loss: 6.7245e-04
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - loss: 7.7432e-04 - val_loss: 7.7708e-04
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - loss: 6.1602e-04 - val_loss: 0.0013
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - loss: 5.8260e-04 - val_loss: 6.1190e-04
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - loss: 6.4005e-04 - val_loss: 9.6779e-04
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - loss: 5.4138e-04 - val_loss: 0.0037
# Epoch 18/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - loss: 7.3996e-04 - val_loss: 0.0013
# Epoch 19/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - loss: 6.1282e-04 - val_loss: 0.0014
# Epoch 20/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - loss: 5.9734e-04 - val_loss: 8.7553e-04
# Epoch 21/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - loss: 5.4251e-04 - val_loss: 5.4064e-04
# Epoch 22/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - loss: 5.1470e-04 - val_loss: 6.2491e-04
# Epoch 23/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - loss: 4.8496e-04 - val_loss: 5.7478e-04
# Epoch 24/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - loss: 6.2307e-04 - val_loss: 0.0016
# Epoch 25/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - loss: 5.5829e-04 - val_loss: 6.5820e-04
# Epoch 26/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - loss: 4.9499e-04 - val_loss: 7.1975e-04
# Epoch 27/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 4.6502e-04 - val_loss: 4.7228e-04
# Epoch 28/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 4.7994e-04 - val_loss: 5.1066e-04
# Epoch 29/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 146ms/step - loss: 4.3134e-04 - val_loss: 0.0012
# Epoch 30/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - loss: 5.0023e-04 - val_loss: 5.5113e-04
# Epoch 31/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 4.0649e-04 - val_loss: 4.7161e-04
# Epoch 32/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - loss: 3.8946e-04 - val_loss: 7.9261e-04
# Epoch 33/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 4.2033e-04 - val_loss: 7.3310e-04
# Epoch 34/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 4.0115e-04 - val_loss: 5.8248e-04
# Epoch 35/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - loss: 3.7937e-04 - val_loss: 7.7746e-04
# Epoch 36/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 4.0181e-04 - val_loss: 9.0289e-04
# Epoch 37/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 4.1837e-04 - val_loss: 5.5304e-04
# Epoch 38/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - loss: 3.7563e-04 - val_loss: 0.0017
# Epoch 39/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 5.5266e-04 - val_loss: 4.2863e-04
# Epoch 40/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 4.2503e-04 - val_loss: 4.9220e-04
# Epoch 41/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - loss: 3.8247e-04 - val_loss: 3.6984e-04
# Epoch 42/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - loss: 3.6721e-04 - val_loss: 9.7385e-04
# Epoch 43/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 4.9011e-04 - val_loss: 5.0696e-04
# Epoch 44/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 5.3671e-04 - val_loss: 0.0012
# Epoch 45/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - loss: 3.8442e-04 - val_loss: 4.2300e-04
# Epoch 46/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 3.4685e-04 - val_loss: 0.0010
# Epoch 47/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 3.4330e-04 - val_loss: 6.9617e-04
# Epoch 48/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 3.6228e-04 - val_loss: 4.6336e-04
# Epoch 49/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 3.6742e-04 - val_loss: 0.0010
# Epoch 50/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - loss: 3.5039e-04 - val_loss: 2.9586e-04
# Epoch 51/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - loss: 4.1221e-04 - val_loss: 5.6114e-04
# Epoch 52/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - loss: 3.2887e-04 - val_loss: 3.0114e-04
# Epoch 53/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 3.5031e-04 - val_loss: 4.5244e-04
# Epoch 54/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 3.4065e-04 - val_loss: 0.0016
# Epoch 55/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - loss: 3.7985e-04 - val_loss: 8.0745e-04
# Epoch 56/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 3.9966e-04 - val_loss: 2.7645e-04
# Epoch 57/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 3.1510e-04 - val_loss: 9.0301e-04
# Epoch 58/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 3.4580e-04 - val_loss: 3.0914e-04
# Epoch 59/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 3.3097e-04 - val_loss: 4.3667e-04
# Epoch 60/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 3.7616e-04 - val_loss: 3.2000e-04
# Epoch 61/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 2.9331e-04 - val_loss: 2.6335e-04
# Epoch 62/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 2.7480e-04 - val_loss: 8.4891e-04
# Epoch 63/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - loss: 3.4363e-04 - val_loss: 2.5690e-04
# Epoch 64/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 2.8402e-04 - val_loss: 4.8484e-04
# Epoch 65/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - loss: 2.6162e-04 - val_loss: 4.2764e-04
# Epoch 66/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 2.7777e-04 - val_loss: 7.2716e-04
# Epoch 67/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 2.9608e-04 - val_loss: 3.1801e-04
# Epoch 68/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 2.9536e-04 - val_loss: 2.6546e-04
# Epoch 69/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - loss: 3.4451e-04 - val_loss: 3.8165e-04
# Epoch 70/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 144ms/step - loss: 2.7737e-04 - val_loss: 5.2000e-04
# Epoch 71/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - loss: 3.0784e-04 - val_loss: 2.7639e-04
# Epoch 72/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 2.8901e-04 - val_loss: 6.0734e-04
# Epoch 73/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - loss: 3.2780e-04 - val_loss: 2.6526e-04
# Epoch 74/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 2.6087e-04 - val_loss: 2.5313e-04
# Epoch 75/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - loss: 2.8142e-04 - val_loss: 5.1593e-04
# Epoch 76/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - loss: 3.1609e-04 - val_loss: 2.2715e-04
# Epoch 77/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - loss: 2.6026e-04 - val_loss: 0.0019
# Epoch 78/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - loss: 4.3307e-04 - val_loss: 3.9291e-04
# Epoch 79/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - loss: 2.5911e-04 - val_loss: 4.5050e-04
# Epoch 80/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - loss: 2.7050e-04 - val_loss: 4.7556e-04
# Epoch 81/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - loss: 2.5960e-04 - val_loss: 3.1671e-04
# Epoch 82/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 12s 178ms/step - loss: 3.1977e-04 - val_loss: 5.0519e-04
# Epoch 83/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - loss: 2.6441e-04 - val_loss: 3.3530e-04
# Epoch 84/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - loss: 2.3790e-04 - val_loss: 2.2001e-04
# Epoch 85/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 214ms/step - loss: 2.4583e-04 - val_loss: 6.1895e-04
# Epoch 86/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 223ms/step - loss: 2.3932e-04 - val_loss: 2.7780e-04
# Epoch 87/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 226ms/step - loss: 2.7396e-04 - val_loss: 4.2200e-04
# Epoch 88/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 2.0394e-04 - val_loss: 2.0010e-04
# Epoch 89/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 263ms/step - loss: 2.3229e-04 - val_loss: 2.3388e-04
# Epoch 90/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - loss: 2.4204e-04 - val_loss: 2.9704e-04
# Epoch 91/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - loss: 2.2596e-04 - val_loss: 4.8981e-04
# Epoch 92/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - loss: 2.6014e-04 - val_loss: 2.2055e-04
# Epoch 93/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - loss: 2.4657e-04 - val_loss: 3.1923e-04
# Epoch 94/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 12s 300ms/step - loss: 2.4915e-04 - val_loss: 1.8801e-04
# Epoch 95/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 13s 316ms/step - loss: 2.3707e-04 - val_loss: 2.3927e-04
# Epoch 96/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 20s 295ms/step - loss: 2.2935e-04 - val_loss: 2.0820e-04
# Epoch 97/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 12s 284ms/step - loss: 2.3906e-04 - val_loss: 7.8692e-04
# Epoch 98/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 12s 293ms/step - loss: 2.8441e-04 - val_loss: 1.9181e-04
# Epoch 99/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - loss: 2.1418e-04 - val_loss: 6.9366e-04
# Epoch 100/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 21s 257ms/step - loss: 2.3750e-04 - val_loss: 1.9620e-04

# %%
# 10. Dự báo dữ liệu test
y_pred = model.predict(X_test)

# 13. Dự báo 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
x_input = x_input.reshape((1, time_step, 1))

temp_input = x_input[0].tolist()
temp_input = temp_input[0]
days_to_predict = 90
lst_output = []
n_steps = 100
i = 0
while(i < days_to_predict):
    if(len(temp_input) > 100):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i + 1

test_data = test_data[time_step:]
lst_output.insert(0, test_data[-1])
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 997ms/step

# %%
train_data = scaler.inverse_transform(train_data)
test_data = scaler.inverse_transform(test_data)
y_pred = scaler.inverse_transform(y_pred)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Đánh giá MAE
mae = mean_absolute_error(test_data, y_pred)
print("Mean Absolute Error (MAE):", mae)

# Đánh giá MSE
mse = mean_squared_error(test_data, y_pred)
print("Mean Squared Error (MSE):", mse)

# Đánh giá RMSE
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Đánh giá MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(test_data, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Error (MAE): 1.7169274187407002
# Mean Squared Error (MSE): 5.185017634141139
# Root Mean Squared Error (RMSE): 2.277063379473909
# Mean Absolute Percentage Error (MAPE): 0.9689542233141055

# %%
# 14. Vẽ hình
plt.figure(figsize=(20, 12))

# train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
train_data_index = df[0:train_size].index
plt.plot(train_data_index, train_data)

test_data_index = df[train_size:len(df)].index
plt.plot(test_data_index, test_data)

plt.plot(test_data_index, y_pred)



next_30days_index = pd.date_range(start=df.index[-2] + pd.Timedelta(days=1), periods=31)
next_60days_index = pd.date_range(next_30days_index[-1] + pd.Timedelta(days=1), periods=30)
next_90days_index = pd.date_range(next_60days_index[-1] + pd.Timedelta(days=1), periods=30)

plt.plot(next_30days_index, scaler.inverse_transform(lst_output)[:31])

plt.plot(next_60days_index, scaler.inverse_transform(lst_output)[31:61])

plt.plot(next_90days_index, scaler.inverse_transform(lst_output)[61:])

plt.legend(['Train', 'Test', 'Predict', 'Predict Day 1-30', 'Predicted Day 31-60', 'Predicted Day 61-90'])
plt.show()
print(len(test_data))
print(len(y_pred))

print(len(train_data))
# Out:
# 315
# 315
# 1259
